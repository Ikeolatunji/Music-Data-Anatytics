# %%
import DataLoadingAndExploration as etl

# %%
wrangler = etl.DataExplorer("./data.csv")

# %%
data =  wrangler.load_data()

# %%
len(data)
# Out:
# 170653

# %%
data.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                                    c  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
data[["valence", "energy"]]
# Out:
#         valence  energy
# 0        0.0594   0.211
# 1        0.9630   0.341
# 2        0.0394   0.166
# 3        0.1650   0.309
# 4        0.2530   0.193
# ...         ...     ...
# 170648   0.6080   0.808
# 170649   0.7340   0.753
# 170650   0.6370   0.858
# 170651   0.1950   0.623
# 170652   0.6420   0.721
#
# [170653 rows x 2 columns]

# %%
wrangler.check_missing_values()
# Out:
# valence             0
# year                0
# acousticness        0
# c                   0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# dtype: int64

# %%
wrangler.describe_data()
# Out:
#              valence           year   acousticness   danceability  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        0.528587    1976.787241       0.502115       0.537396
# std         0.263171      25.917853       0.376032       0.176138
# min         0.000000    1921.000000       0.000000       0.000000
# 25%         0.317000    1956.000000       0.102000       0.415000
# 50%         0.540000    1977.000000       0.516000       0.548000
# 75%         0.747000    1999.000000       0.893000       0.668000
# max         1.000000    2020.000000       0.996000       0.988000
#
#         duration_ms         energy       explicit  instrumentalness  \
# count  1.706530e+05  170653.000000  170653.000000     170653.000000
# mean   2.309483e+05       0.482389       0.084575          0.167010
# std    1.261184e+05       0.267646       0.278249          0.313475
# min    5.108000e+03       0.000000       0.000000          0.000000
# ...

# %%
# Come back
# wrangler.additional_statistics("valence")

# %%
wrangler.bar_plot("popularity")
# Out:
# c:\Users\ikeol\Downloads\dataset\DataLoadingAndExploration.py:50: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=self.data[column], palette='viridis')

# %%
wrangler.scatter_plot( "popularity", "tempo")

# %%
import RankingArtistAndMusic as raam
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 import RankingArtistAndMusic as raam
#
# ModuleNotFoundError: No module named 'RankingArtistAndMusic'

# %%
import DataPreProcessor as dpp

# %%
dp = dpp.DataPreprocessor(data)

# %%
# TO IMPLEMENT THIS YOU WOULD NEED TO FIND THE COLUMN NAME 
# dp.handle_missing_values()

# %%
import RecommendationSystem as rs

# %%
r = rs.RecommendationSystem(data, ["valence", "tempo", "year", "danceability", "popularity", "explicit"])

# %%
r.recommend(10)
# Out:
#         valence  year  acousticness  \
# 75918     0.691  1930         0.982
# 23233     0.367  1942         0.993
# 76510     0.766  1936         0.716
# 77866     0.485  1947         0.918
# 126137    0.342  1946         0.979
#
#                                                   artists  danceability  \
# 75918                   ['Λαϊκή Ορχήστρα Μιχάλη Φελουζή']         0.436
# 23233   ['Wolfgang Amadeus Mozart', 'Jarmila Novotna',...         0.336
# 76510                                  ['Carmen Miranda']         0.609
# 77866                                      ['C. Ashwath']         0.414
# 126137  ['George Frideric Handel', 'The Liverpool Phil...         0.350
#
#         duration_ms  energy  explicit                      id  \
# 75918        162560   0.336         0  3CNTRBPv1xFDfFiab7BUyf
# 23233        155533   0.137         0  0yRwXcDfDuaVsXv0bXzRyz
# 76510        180333   0.326         0  6Upzf5bwmb37P3xObNPjIQ
# ...

# %%
import Clustering as k_means

# %%
data.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
import Clustering as k_means

# %%
df = data

# %%
k = k_means.SongClustering(df, ["valence", "tempo", "year", "danceability", "popularity", "explicit"])

# %%
k.create_clusters()

# %%
k.visualize_clusters()

# %%
recommendations = k.get_recommendations_by_cluster("Frank")
recommendations
# Out:
# 93053
#         valence  year  acousticness  \
# 0        0.0594  1921         0.982
# 1        0.9630  1921         0.732
# 2        0.0394  1921         0.961
# 3        0.1650  1921         0.967
# 4        0.2530  1921         0.957
# ...         ...   ...           ...
# 159536   0.7790  1964         0.937
# 159549   0.6610  1964         0.575
# 159674   0.8090  1965         0.696
# 159722   0.6480  1965         0.806
# 159745   0.9270  1965         0.360
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %%
k.get_random_artist_index_by_name("Drake")
# Out:
# 122168

# %%
k.get_recommendations_by_cluster("drake")
# Out:
# 73805
#         valence  year  acousticness                   artists  danceability  \
# 5606      0.197  1950        0.9900       ['Ella Fitzgerald']         0.354
# 5806      0.206  1951        0.9070       ['Thelonious Monk']         0.542
# 6206      0.927  1953        0.8310          ['Gayla Peevey']         0.853
# 6409      0.316  1954        0.9720          ['Judy Garland']         0.204
# 6410      0.560  1954        0.7280           ['Dean Martin']         0.591
# ...         ...   ...           ...                       ...           ...
# 170462    0.816  2020        0.2730  ['Russ', 'Busta Rhymes']         0.745
# 170534    0.261  2020        0.0941           ['Jhay Cortez']         0.450
# 170565    0.286  2020        0.9240            ['Kali Uchis']         0.443
# 170594    0.473  2020        0.0647    ['Jeezy', 'Rick Ross']         0.721
# 170621    0.362  2020        0.7190            ['Dan + Shay']         0.420
#
# ...

# %%
import DataLoadingAndExploration as Ke

# %%
file_path = "./data.csv"
explorer = Ke.DataExplorer(file_path)
data = explorer.load_data()

# %%
stats = Ke.AdditionalStatistics(data)
numeric_columns = data.select_dtypes(include=["number"]).columns[:10]

# %%
print("Mean of the first 10 numerical columns:")
for col in numeric_columns:
    print(f"{col}: {stats.mean(col)}")
# Out:
# Mean of the first 10 numerical columns:
# valence: 0.5285872111424939
# year: 1976.7872407751402
# acousticness: 0.5021147637067032
# danceability: 0.5373955347986852
# duration_ms: 230948.3106655025
# energy: 0.4823888351127728
# explicit: 0.08457513199299163
# instrumentalness: 0.16700958082940237
# key: 5.199844128143074
# liveness: 0.20583865545873795

# %%
import pandas as pd
import numpy as np

# %%
data_path = "./data.csv"  
genres_path = "./data_genres.csv"

# %%
data = pd.read_csv(data_path)
genres_data = pd.read_csv(genres_path)

# %%
preprocessor = DataPreprocessor(data)

# %%
print("Missing values before handling:")
print(data.isnull().sum())
# Out:
# Missing values before handling:
# valence             0
# year                0
# acousticness        0
# c                   0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# dtype: int64

# %%
print("\nProcessed Data Sample:")
print(processed_data.head())
# Out:
# Processed Data Sample:
#      A     B      C  D    E
# 0  1.0  10.0  100.0  x  4.0
# 1  2.0  32.5  200.0  y  2.5
# 2  3.0  30.0  300.0  z  3.5
# 3  4.0  40.0  275.0  w  4.5
# 4  5.0  50.0  500.0  v  5.5

# %%
print("\nMissing values after handling:")
print(processed_data.isnull().sum())
# Out:
# Missing values after handling:
# A    0
# B    0
# C    0
# D    0
# E    0
# dtype: int64
